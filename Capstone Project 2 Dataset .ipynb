# %% [markdown]
# # Capstone Project 2

# %% [markdown]
# ## Building the dataset

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from time import sleep
import re
import time
from tqdm import tqdm

# %% [markdown]
# ### Building a dataframe with the 50 most rated boardgames (code found on the Internet)

# %%
def req(msg, slp=0.2):
    """Make fault tolerant BGG server requests."""
    # Sleep to make sure you are not pinging the server to frequently
    sleep(slp)
    # Keep trying requests until status-code is 200
    status_code = 500
    while status_code != 200:
        sleep(slp)
        try:
            r = requests.get(msg)
            status_code = r.status_code
            # if status_code != 200:
                # print("Server Error! Response Code %i. Retrying..." % (r.status_code))
        except:
            # print("An exception has occurred, probably a momentory loss of connection. Waiting three seconds...")
            sleep(3)
    return r

# %%
def request(msg, slp=1):
    '''A wrapper to make robust https requests.'''
    status_code = 500  # Want to get a status-code of 200
    while status_code != 200:
        sleep(slp)  # Don't ping the server too often
        try:
            r = requests.get(msg)
            status_code = r.status_code
            if status_code != 200:
                print("Server Error! Response Code %i. Retrying..." % (r.status_code))
        except:
            print("An exception has occurred, probably a momentory loss of connection. Waiting one seconds...")
            sleep(1)
    return r

# %%
# Get full HTML for a specific page in the full listing of boardgames sorted by 
r = request("https://boardgamegeek.com/browse/boardgame/page/%i?sort=numvoters&sortdir=desc" % (1,))
soup = BeautifulSoup(r.text, "html.parser")    
    
# Get rows for the table listing all the games on this page
table = soup.find_all("tr", attrs={"id": "row_"})  # Get list of all the rows (tags) in the list of games on this page
df = pd.DataFrame(columns=["id", "name", "nrate", "pic_url"], index=range(len(table)))  # DF to hold this pages results
    
# Loop through each row and pull out the info for that game
for idx, row in enumerate(table):
    # Row may or may not start with a "boardgame rank" link, if YES then strip it
    links = row.find_all("a")
    if "name" in links[0].attrs.keys():
        del links[0]
    gamelink = links[1]  # Get the relative URL for the specific game
    gameid = int(gamelink["href"].split("/")[2])  # Get the game ID by parsing the relative URL
    gamename = gamelink.contents[0]  # Get the actual name of the game as the link contents
    imlink = links[0]  # Get the URL for the game thumbnail
    thumbnail = imlink.contents[0]["src"]

    ratings_str = row.find_all("td", attrs={"class": "collection_bggrating"})[2].contents[0]
    nratings = int("".join(ratings_str.split()))

    df.iloc[idx, :] = [gameid, gamename, nratings,thumbnail]

sleep(2) # Keep the BGG server happy.

# Prepare a "# of FULL pages of ratings" column to track # API calls needed
df["nfullpages"] = (df["nrate"]-50).apply(round, ndigits=-2)/100  # Round DOWN to nearest 100

# 50 most nrated game
df=df.iloc[0:50]
del df['pic_url']

# %%
print(df.shape)
df
# Out:
# (50, 4)
#         id                                              name  nrate  \
# 0       13                                             Catan  87364
# 1      822                                       Carcassonne  87035
# 2    30549                                          Pandemic  85844
# 3    68448                                         7 Wonders  71104
# 4    36218                                          Dominion  69600
# 5     9209                                    Ticket to Ride  61886
# 6    31260                                          Agricola  58028
# 7     3076                                       Puerto Rico  57424
# 8    40692                                       Small World  54692
# 9   178900                                         Codenames  53435
# 10    2651                                        Power Grid  50937
# 11   70323                                     King of Tokyo  49892
# 12   14996                            Ticket to Ride: Europe  48854
# 13  129622                                       Love Letter  48205
# 14  148228                                          Splendor  47123
# 15     478                                          Citadels  44387
# 16  173346                                    7 Wonders Duel  43234
# 17   39856                                             Dixit  42719
# 18  167791                                 Terraforming Mars  42660
# 19  169786                                            Scythe  42601
# 20   28143                               Race for the Galaxy  41390
# 21  110327                                Lords of Waterdeep  39698
# 22   34635                                         Stone Age  39184
# 23   84876                           The Castles of Burgundy  38227
# 24    1927                                          Munchkin  36786
# 25   65244                                  Forbidden Island  36312
# 26   12333                                 Twilight Struggle  35430
# 27  163412                                         Patchwork  35377
# 28   15987                                     Arkham Horror  34691
# 29      11                                          Bohnanza  34440
# 30  150376                 Dead of Winter: A Crossroads Game  33876
# 31  120677                                     Terra Mystica  33595
# 32   98778                                            Hanabi  33017
# 33      50                                       Lost Cities  32642
# 34  161936                         Pandemic Legacy: Season 1  32603
# 35   41114                                    The Resistance  32417
# 36  230802                                              Azul  32311
# 37   10547                     Betrayal at House on the Hill  31443
# 38   37111              Battlestar Galactica: The Board Game  30364
# 39  131357                                              Coup  30214
# 40  147020                                       Star Realms  29581
# 41   54043                                            Jaipur  29242
# 42   70919                                          Takenoko  28901
# 43     463                              Magic: The Gathering  28562
# 44  121921  Robinson Crusoe: Adventures on the Cursed Island  27929
# 45  133473                                         Sushi Go!  27768
# 46  174430                                        Gloomhaven  27595
# 47   40834                                Dominion: Intrigue  27575
# 48  170216                                        Blood Rage  26905
# 49     181                                              Risk  26737
#
#     nfullpages
# 0        873.0
# 1        870.0
# 2        858.0
# 3        711.0
# 4        696.0
# 5        618.0
# 6        580.0
# 7        574.0
# 8        546.0
# 9        534.0
# 10       509.0
# 11       498.0
# 12       488.0
# 13       482.0
# 14       471.0
# 15       443.0
# 16       432.0
# 17       427.0
# 18       426.0
# 19       426.0
# 20       413.0
# 21       396.0
# 22       391.0
# 23       382.0
# 24       367.0
# 25       363.0
# 26       354.0
# 27       353.0
# 28       346.0
# 29       344.0
# 30       338.0
# 31       335.0
# 32       330.0
# 33       326.0
# 34       326.0
# 35       324.0
# 36       323.0
# 37       314.0
# 38       303.0
# 39       302.0
# 40       295.0
# 41       292.0
# 42       289.0
# 43       285.0
# 44       279.0
# 45       277.0
# 46       275.0
# 47       275.0
# 48       269.0
# 49       267.0

# %% [markdown]
# ### Building a dataframe with the reviews, rates and some information on the 50 most rated boardgames

# %%
def game_info (soup,ID):
    """Get the boardgame information"""
    name=soup('name')[0]["value"]
    year=soup('yearpublished')[0]["value"]
    min_play=soup('minplayers')[0]["value"]
    max_play=soup('maxplayers')[0]["value"]
    min_time=soup('minplaytime')[0]["value"]
    max_time=soup('maxplaytime')[0]["value"]
    min_age=soup('minage')[0]["value"]

    Category=[]
    for a in range(0,10):
        if soup('link')[a]['type']=="boardgamecategory":   
            Category.append(soup('link')[a]["value"])
    category=Category[0]
    return name,year,min_play,max_play,min_time,max_time,min_age,category

# %%
def game_rating_reviews (soup,review,username,rating):
    """Get the boardgames rates and reviews"""
    for nb in range(0,99):
        review.append(soup('comment')[nb]["value"])
        username.append(soup('comment')[nb]["username"])
        rate.append(soup('comment')[nb]["rating"])
    return review,username,rate

# %%
# transform the column with the id as a object column and the column with the number of pages as an integer column
df.id=df.id.astype(str)
df.nfullpages=df.nfullpages.astype(int)
# add a progression bar
for i in tqdm(range(20)):
    # Go through the 30 boardgames
    for a in range(0,50):
        nb_rate=df.nrate[a]
        ID=df.id[a]
        nb_page=df.nfullpages[a]
        # Go through the n pages of reviews
        for b in range (0,nb_page):
            b_str=str(b)
            # Access to each of the boardgame information page by page
            url="https://www.boardgamegeek.com/xmlapi2/thing?id="+ID+"&page="+b_str+"&ratingcomments=1"
            r=requests.get(url)
            soup=BeautifulSoup(r.text)
            # Check if the connection works
            if r.status_code==200:
                review=[]
                username=[]
                rate=[]
                # Get the boardgames information
                name,year,min_play,max_play,min_time,max_time,min_age,category=game_info(soup,ID)
                # Get the boardgames rates & reviews
                review,username,rate=game_rating_reviews(soup,review,username,rate)
                # Building the dataframe for each boardgame
                data={'id':ID,'name':name,'year':year,'min_play':min_play,'max_play':max_play,'min_time':min_time,
                     'max_time':max_time,'min_age':min_age,'category':category,'nb_rate':nb_rate,'username':username,
                     'review':review,'rate':rate}
                df_bgg_onegame=pd.DataFrame(data)
                # Drop the raws without any review
                df_bgg_onegame=df_bgg_onegame.drop(df_bgg_onegame[df_bgg_onegame.review==''].index) 
                # Concatenate the dataframes
                if a==0 & b=='0':
                    df_bgg=df_bgg_onegame.copy()
                else:
                    df_bgg=df_bgg.append(df_bgg_onegame).reset_index(drop=True)
    time.sleep(3)

# %%
# Saving the dataset in a cvs format
df_bgg.to_csv("bgg_review.csv", index=False, encoding="utf-8")
print(df_bgg.shape)
df_bgg
# Out:
# (304910, 13)
#          id   name  year  min_play  max_play  min_time  max_time  min_age  \
# 0        13  Catan  1995         3         4        60       120       10
# 1        13  Catan  1995         3         4        60       120       10
# 2        13  Catan  1995         3         4        60       120       10
# 3        13  Catan  1995         3         4        60       120       10
# 4        13  Catan  1995         3         4        60       120       10
# 5        13  Catan  1995         3         4        60       120       10
# 6        13  Catan  1995         3         4        60       120       10
# 7        13  Catan  1995         3         4        60       120       10
# 8        13  Catan  1995         3         4        60       120       10
# 9        13  Catan  1995         3         4        60       120       10
# 10       13  Catan  1995         3         4        60       120       10
# 11       13  Catan  1995         3         4        60       120       10
# 12       13  Catan  1995         3         4        60       120       10
# 13       13  Catan  1995         3         4        60       120       10
# 14       13  Catan  1995         3         4        60       120       10
# 15       13  Catan  1995         3         4        60       120       10
# 16       13  Catan  1995         3         4        60       120       10
# 17       13  Catan  1995         3         4        60       120       10
# 18       13  Catan  1995         3         4        60       120       10
# 19       13  Catan  1995         3         4        60       120       10
# 20       13  Catan  1995         3         4        60       120       10
# 21       13  Catan  1995         3         4        60       120       10
# 22       13  Catan  1995         3         4        60       120       10
# 23       13  Catan  1995         3         4        60       120       10
# 24       13  Catan  1995         3         4        60       120       10
# 25       13  Catan  1995         3         4        60       120       10
# 26       13  Catan  1995         3         4        60       120       10
# 27       13  Catan  1995         3         4        60       120       10
# 28       13  Catan  1995         3         4        60       120       10
# 29       13  Catan  1995         3         4        60       120       10
# ...     ...    ...   ...       ...       ...       ...       ...      ...
# 304880  181   Risk  1959         2         6       120       120       10
# 304881  181   Risk  1959         2         6       120       120       10
# 304882  181   Risk  1959         2         6       120       120       10
# 304883  181   Risk  1959         2         6       120       120       10
# 304884  181   Risk  1959         2         6       120       120       10
# 304885  181   Risk  1959         2         6       120       120       10
# 304886  181   Risk  1959         2         6       120       120       10
# 304887  181   Risk  1959         2         6       120       120       10
# 304888  181   Risk  1959         2         6       120       120       10
# 304889  181   Risk  1959         2         6       120       120       10
# 304890  181   Risk  1959         2         6       120       120       10
# 304891  181   Risk  1959         2         6       120       120       10
# 304892  181   Risk  1959         2         6       120       120       10
# 304893  181   Risk  1959         2         6       120       120       10
# 304894  181   Risk  1959         2         6       120       120       10
# 304895  181   Risk  1959         2         6       120       120       10
# 304896  181   Risk  1959         2         6       120       120       10
# 304897  181   Risk  1959         2         6       120       120       10
# 304898  181   Risk  1959         2         6       120       120       10
# 304899  181   Risk  1959         2         6       120       120       10
# 304900  181   Risk  1959         2         6       120       120       10
# 304901  181   Risk  1959         2         6       120       120       10
# 304902  181   Risk  1959         2         6       120       120       10
# 304903  181   Risk  1959         2         6       120       120       10
# 304904  181   Risk  1959         2         6       120       120       10
# 304905  181   Risk  1959         2         6       120       120       10
# 304906  181   Risk  1959         2         6       120       120       10
# 304907  181   Risk  1959         2         6       120       120       10
# 304908  181   Risk  1959         2         6       120       120       10
# 304909  181   Risk  1959         2         6       120       120       10
#
#                   category  nb_rate            username  \
# 0              Negotiation    87205       Deleted010518
# 1              Negotiation    87205          fliptrackr
# 2              Negotiation    87205            ShirKhan
# 3              Negotiation    87205              bkunes
# 4              Negotiation    87205          BenjoBaker
# 5              Negotiation    87205        fformighieri
# 6              Negotiation    87205           Tibetgeek
# 7              Negotiation    87205             Podicle
# 8              Negotiation    87205          ividdythou
# 9              Negotiation    87205             GamerVP
# 10             Negotiation    87205        mickeben1979
# 11             Negotiation    87205           Sourceror
# 12             Negotiation    87205              darKOR
# 13             Negotiation    87205         jglazebrook
# 14             Negotiation    87205            Mixelo82
# 15             Negotiation    87205         draconiscor
# 16             Negotiation    87205            Ma3dhros
# 17             Negotiation    87205          lusoresgso
# 18             Negotiation    87205           chen01364
# 19             Negotiation    87205          dougthonus
# 20             Negotiation    87205              cypar7
# 21             Negotiation    87205             hreimer
# 22             Negotiation    87205           daredevil
# 23             Negotiation    87205              hurkle
# 24             Negotiation    87205               Thesp
# 25             Negotiation    87205              bnpihl
# 26             Negotiation    87205             Zagatto
# 27             Negotiation    87205              turtle
# 28             Negotiation    87205                PatB
# 29             Negotiation    87205        mnickerson30
# ...                    ...      ...                 ...
# 304880  Territory Building    26737           Catamount
# 304881  Territory Building    26737                lomn
# 304882  Territory Building    26737          Piper 2009
# 304883  Territory Building    26737       TheLegoPirate
# 304884  Territory Building    26737        Toxic Meeple
# 304885  Territory Building    26737         PaulECoyote
# 304886  Territory Building    26737      rescue_toaster
# 304887  Territory Building    26737         oninoyakamo
# 304888  Territory Building    26737           MARCUSRPG
# 304889  Territory Building    26737      jonatanrullman
# 304890  Territory Building    26737             Maolvar
# 304891  Territory Building    26737      My fathers son
# 304892  Territory Building    26737           GusterFan
# 304893  Territory Building    26737            emptyset
# 304894  Territory Building    26737               JensR
# 304895  Territory Building    26737           Oninohugo
# 304896  Territory Building    26737             Croquet
# 304897  Territory Building    26737             che2487
# 304898  Territory Building    26737          VolleyGame
# 304899  Territory Building    26737       derblaueClaus
# 304900  Territory Building    26737             Sounder
# 304901  Territory Building    26737            tormariu
# 304902  Territory Building    26737        Schmusetiger
# 304903  Territory Building    26737      Mark van Varik
# 304904  Territory Building    26737        phatmanphill
# 304905  Territory Building    26737             Altasia
# 304906  Territory Building    26737  battlecryoffreedom
# 304907  Territory Building    26737            VaultBoy
# 304908  Territory Building    26737           dpbernath
# 304909  Territory Building    26737       chrisgledhill
#
#                                                    review  rate
# 0       2008-04-05 \r\r\r\r\n\r\r\r\r\nDave Loved the ...   7.2
# 1       Like this game (even though I don't own it).  ...   7.2
# 2       Classic. Besides that, fairly random and often...   7.2
# 3       Enjoyable game, challenge is getting at least ...   7.2
# 4       What can I say?  If you haven't played Settler...   7.2
# 5       Esse jogo é uma excelente maneira de introduzi...   7.2
# 6       First Euro-style strategy game. It was fun, go...   7.2
# 7       Haven't played this for a while, mainly becaus...   7.2
# 8       So much hate for this game floating around, I ...   7.2
# 9       One of the games where I ended up with most of...   7.2
# 10                 Fun game when playing it with a group.   7.2
# 11      Without the expansions it's not fun. \r\r\r\r\...   7.2
# 12      [b]+ compact version[/b]\r\r\r\r\nclassic, lan...   7.2
# 13      Still love it.... Just not as new as a lot of ...   7.2
# 14      Con el descubrí de nuevo los juegos de mesa, d...   7.2
# 15      Simple game with a great graphic, simple gamep...   7.2
# 16      This was my Gateway Game. Played nearly 100 ti...   7.2
# 17      jeremy\r\r\r\r\nluke\r\r\r\r\nzach\r\r\r\r\n\r...   7.2
# 18                                              已開已玩 Home   7.2
# 19      Currently, this sits on my list as my favorite...  10.0
# 20      I know it says how many plays, but many, many ...  10.0
# 21               i will never tire of this game.. Awesome  10.0
# 22      This is probably the best game I ever played. ...  10.0
# 23      Fantastic game. Got me hooked on games all ove...  10.0
# 24      One of the best games ever created. Period. Ne...  10.0
# 25      Game itself is 9. Only strategy game my family...  10.0
# 26      This is a great game.  I've even got a number ...  10.0
# 27      One of my all time favorite games. I usually o...  10.0
# 28      Settlers is a gem. If you havn't played it I s...  10.0
# 29                                           Old Faithful  10.0
# ...                                                   ...   ...
# 304880  Another game that hasn't aged well.  Even as a...   2.0
# 304881  Classic Risk? Not gonna play it. But I'll cons...   2.0
# 304882                                    Childhood game.   2.0
# 304883  Played this a ton as a kid and still have it f...   2.0
# 304884  Lost out to Monopoly in terms of enjoyability,...   2.0
# 304885  Goes on for too long.  Relies heavily on meta-...   2.0
# 304886  The escalating armies gained by matched cards ...   2.0
# 304887  Taught me geography as a child.\r\n\r\nAs a te...   2.0
# 304888  Okay, i outnumber your armies 5:1 and I still ...   2.0
# 304889  1993 Swedish edition\r\nInventoried: 2013-09-2...   2.0
# 304890  Shallow game mechanics and limited tactical op...   2.0
# 304891              Dice rolling exercise for suckers...    2.0
# 304892  I know I'm not typically into war themed games...   2.0
# 304893  Outdated. Takes way too long and encourages tu...   2.0
# 304894  Maybe I'm biased because I tend to lose this g...   2.0
# 304895             Guilty of spawning so many crap games.   2.0
# 304896                Classic game, luck is dominating it   2.0
# 304897  Nostalgiaaaaa....\r\n\r\nPart of Trade for new...   2.0
# 304898                Dice battles... bleeaauuchhh, ptui!   2.0
# 304899  The great Grandfather of light Wargaming. But ...   2.0
# 304900  There are better games out there that do the s...   2.0
# 304901                             Missing X (10?) plays.   2.0
# 304902          It's Risk. What else do I have to say? =\   2.0
# 304903                            I ABSOLUTELY HATE RISK.   2.0
# 304904  this game is too long for the high amounts of ...   2.0
# 304905              Replaced by every other version owned   2.0
# 304906  Worse than Axis & Allies with even fewer rewar...   2.0
# 304907  We have to play how long for one player to eme...   2.0
# 304908  Hated this game when I played it as a kid; sho...   2.0
# 304909  Diplomatio-ludo klasika simulanta mondo-skalan...   2.0
#
# [304910 rows x 13 columns]
